# %% [markdown]
# ![image.png](attachment:image.png)

# %%
email = "Amit_ml@gmail.edu"

if email.count("@") == 1 and "." in email.split("@")[1]:
    print("Valid email")

else:
    print("Invalid email")
# Out:
# Valid email

# %%
print(email[0:7])

 # or
e
# Out:
# Amit_ml
