# %% [markdown]
# ![image.png](attachment:image.png)

# %%
email = "Amit_ml@gmail.edu"

if email.count("@") == 1 and "." in email.split("@")[1]:
    print("Valid email")

else:
    print("Invalid email")
# Out:
# Valid email

# %%
print(email[0:7])

# ---------------------or--------------------------
 
print(email.split("@")[0])
# Out:
# Amit_ml
# Amit_ml

# %%
print(email[8:13])

# ---------------------or--------------------------

domain = email.split("@")[1].split(".")[0]
print(domain)
# Out:
# gmail
# gmail

# %%
if email.endswith(".com"):
    print("Commercial Domain")

elif email.endswith(".edu"):
    print("Educational Domain")

else:
    print("Other Domain")


# ---------------------or--------------------------

if email [-4:] == ".com":
    print("Commercial Domain")

elif email [-4:] == ".edu":
    print("Educational Domain")

else:
    print("Other Domain")
# Out:
# Educational Domain
# Educational Domain

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
msg= "###!!@mocleW EPGTQ!!!6789"
message = msg.split("@")[1].split("!")[0]
print(message)
# Out:
# mocleW EPGTQ

# %%
a = message[5::-1]

#....................or......................

# a=message.split(" ")[0][::-1]

print(a)
print(a + message[6:])
# Out:
# Welcom
# Welcom EPGTQ

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
msg2 = "&&&**$gnirtS PLIO!!@1234"
message2 = msg2.split("$")[1].split("!")[0]
print(message2)
# Out:
# gnirtS PLIO

# %%
first2 = message2[5::-1]

#....................or......................

#first2 =message2.split(" ")[0][::-1]


second2 = message2[7:].replace("I" , "E").replace("O" , "U")

print (first2 +" "+ second2)
# Out:
# String PLEU

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
msg3 = "##$$$@!yalpstcejorp EPUVT****9887"
message3 = msg3.split("!")[1].split("*")[0]
print(message3)
# Out:
# yalpstcejorp EPUVT

# %%
first3 = message3[11::-1]
#....................or......................

# message3.split(" ")[0][::-1]

second3 = message3[12:].replace("E" , "A").replace("U" , "O")
print (first3 +" "+ second3)
# Out:
# projectsplay  APOVT
