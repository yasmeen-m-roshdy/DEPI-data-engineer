# %%
print("my name is","yasmeen",",my age is :", 22)
# Out:
# my name is yasmeen ,my age is : 22

# %%
a="y"
print(type(a))

x=30.5
print(type(x))

b=3
type(b)
# Out:
# <class 'str'>
# <class 'float'>
# int
